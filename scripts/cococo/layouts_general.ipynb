# %%
import networkx as nx
import mqt.qecc.cococo.layouts as layouts
import plotting
import importlib
import matplotlib.pyplot as plt

# %%
factories = []
m, n = 5,5
g, data_qubit_locs, _ = layouts.gen_layout_scalable("pair", m, n, factories, remove_edges = False)

# %%
size = (6,6)
plotting.plot_lattice(g, size, data_qubit_locs, factories)

# %%
factories = []
m, n = 5,5
g, data_qubit_locs, _ = layouts.gen_layout_scalable("row", m, n, factories, remove_edges = False)

# %%
size = (6,6)
plotting.plot_lattice(g, size, data_qubit_locs, factories)

# %%
factories = []
m, n = 4, 4
g, data_qubit_locs, _ = layouts.gen_layout_scalable("hex", m, n, factories, remove_edges = False)

# %%
size = (10,10)
plotting.plot_lattice(g, size, data_qubit_locs, factories)

# %%
factories = [(8,0),(-3,6),(8,22),(-2,-1),(8,17),(-1,24),(7,24),(-4,15)]
m, n = 12,6
g, data_qubit_locs, factory_ring = layouts.gen_layout_scalable("row", m, n, factories, remove_edges = False)
print(factory_ring)
# Out:
# [(-4, 17), (8, 0), (8, 9), (-3, 6), (9, 8), (8, 18), (-3, 15), (9, 17), (-3, 24), (-4, 1), (-2, -1), (-1, -2), (-2, -2), (-4, 10), (1, 24), (-4, 19), (8, 2), (9, 1), (0, -2), (8, 11), (9, 10), (-3, 8), (3, 24), (9, 19), (-3, 17), (-4, 3), (-4, 12), (-4, 21), (8, 4), (9, 3), (-3, 1), (-3, 10), (9, 12), (9, 21), (-3, 19), (-4, 5), (-4, 14), (-4, 23), (7, 23), (5, -2), (9, 5), (-3, 3), (9, 14), (-3, 12), (-3, 21), (7, -2), (-4, 7), (-4, 16), (9, -1), (9, 7), (-3, 5), (-3, 14), (9, 16), (-3, 23), (8, 20), (-4, 0), (-4, 9), (-3, -1), (9, 0), (9, 9), (-3, 7), (-3, 16), (1, -2), (8, 13), (8, 22), (-4, 2), (2, 24), (3, -2), (6, 24), (9, 2), (-3, 0), (-3, 9), (4, 24), (8, 6), (-3, 18), (8, 15), (-4, 4), (-3, 2), (-3, 11), (8, 8), (8, 17), (-4, 18), (-1, 24), (-2, 24), (-3, 4), (8, 1), (8, 10), (8, 19), (9, 18), (0, 24), (-4, 11), (-4, 20), (8, 3), (8, 12), (9, 11), (8, 21), (9, 20), (-4, 13), (-4, 22), (8, 5), (9, 4), (2, -2), (8, 14), (9, 13), (5, 24), (8, 23), (9, 22), (-3, 20), (6, -2), (-
# ...

# %%
size = (10,14)
plotting.plot_lattice(g, size, data_qubit_locs, factories)
